# %%
import pandas as pd

# %%
df_1=pd.read_csv('trip1_sensors.csv')
df_2 = pd.read_csv('trip2_sensors.csv')

# %%
df_1['latitude'].unique()
# Out:
# array([40.44744479, 40.44744479, 40.44745352, 40.44746546, 40.44748706,
#        40.44752653, 40.44758119, 40.44764584, 40.44772178, 40.4478022 ,
#        40.4478945 , 40.44799551, 40.44809976, 40.44820922, 40.44831656,
#        40.44838162, 40.44852375, 40.44862237, 40.44870556, 40.4488069 ,
#        40.44889733, 40.44899541, 40.44909478, 40.44919864, 40.44930653,
#        40.44940868, 40.44951158, 40.44961826, 40.44972729, 40.44983636,
#        40.44993861, 40.45003523, 40.45013344, 40.45021268, 40.45027839,
#        40.4503305 , 40.45035882, 40.45037874, 40.45038431, 40.45038512,
#        40.45038876, 40.45040204, 40.45044096, 40.45043817, 40.45044258,
#        40.45062508, 40.450697  , 40.45078483, 40.45088585, 40.45099081,
#        40.45109555, 40.45118812, 40.45125824, 40.45130596, 40.45132074,
#        40.45132483, 40.45134417, 40.45138067, 40.4513741 , 40.45155985,
#        40.45167113, 40.45179362, 40.45191394, 40.45202889, 40.45213208,
# ...

# %%
df_1['timestamp'].head(10)
# Out:
# 0    1.492639e+09
# 1    1.492639e+09
# 2    1.492639e+09
# 3    1.492639e+09
# 4    1.492639e+09
# 5    1.492639e+09
# 6    1.492639e+09
# 7    1.492639e+09
# 8    1.492639e+09
# 9    1.492639e+09
# Name: timestamp, dtype: float64

# %%
df_1['speed'].unique()
# Out:
# array([ 0.        ,  0.41      ,  1.47000003,  3.05999994,  4.78999996,
#         6.48000002,  7.28999996,  8.22999954,  9.56999969, 10.72000027,
#        11.43000031, 11.94999981, 12.13000011, 11.92000008, 11.71000004,
#        11.22000027, 10.90999985, 10.56000042, 10.44999981, 10.93999958,
#        11.40999985, 11.84000015, 12.23999977, 12.46000004, 12.35999966,
#        12.17000008, 12.14000034, 12.73999977, 12.63000011, 12.21000004,
#        11.68999958, 10.38000011,  8.78999996,  7.09000015,  5.26999998,
#         2.91000009,  1.36000001,  0.41999999,  0.16      ,  0.44999999,
#         2.22000003,  4.76000023,  6.69000006,  7.92999983,  7.80000019,
#         8.92000008, 10.35000038, 11.89999962,  5.01000023,  1.15999997,
#         0.55000001,  3.28999996,  5.23999977,  9.11999989, 11.80000019,
#        13.78999996, 14.43999958, 14.14000034, 13.        , 11.31999969,
#        10.11999989,  8.89000034,  6.96000004,  6.6500001 ,  8.10999966,
# ...

# %%
df_2
# Out:
#          timestamp   latitude  longitude  speed  accelerometerX  \
# 0     1.493002e+09  40.449893 -79.944788  10.25        0.043274
# 1     1.493002e+09  40.449980 -79.944825  10.09        0.084808
# 2     1.493002e+09  40.449980 -79.944825  10.09       -0.017670
# 3     1.493002e+09  40.449980 -79.944825  10.09        0.017212
# 4     1.493002e+09  40.449980 -79.944825  10.09        0.020630
# ...            ...        ...        ...    ...             ...
# 1982  1.493002e+09  40.447453 -79.944189   0.00        0.039581
# 1983  1.493002e+09  40.447453 -79.944189   0.00       -0.056076
# 1984  1.493002e+09  40.447452 -79.944189   0.00       -0.034546
# 1985  1.493002e+09  40.447452 -79.944189   0.00        0.043716
# 1986  1.493002e+09  40.447452 -79.944189   0.00        0.026794
#
#       accelerometerY  accelerometerZ     gyroX     gyroY     gyroZ
# 0          -1.041153        0.208801  0.071739 -0.041947  0.026432
# ...
