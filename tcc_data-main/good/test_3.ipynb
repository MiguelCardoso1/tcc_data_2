# %%
import pandas as pd

# %%
pd.read_csv('good1_sensors.csv')
# Out:
#         timestamp   latitude  longitude  speed  accelerometerX  \
# 0    1.492617e+09  40.463026 -79.930931   0.00        0.002365
# 1    1.492617e+09  40.463026 -79.930931   0.00        0.018127
# 2    1.492617e+09  40.463026 -79.930931   0.00        0.034073
# 3    1.492617e+09  40.463026 -79.930931   0.00        0.009384
# 4    1.492617e+09  40.463026 -79.930931   0.00        0.009460
# ..            ...        ...        ...    ...             ...
# 545  1.492617e+09  40.472473 -79.925819   5.63        0.052963
# 546  1.492617e+09  40.472473 -79.925819   5.63        0.029984
# 547  1.492617e+09  40.472509 -79.925800   3.63        0.060654
# 548  1.492617e+09  40.472509 -79.925800   3.63        0.013321
# 549  1.492617e+09  40.472509 -79.925800   3.63        0.030090
#
#      accelerometerY  accelerometerZ     gyroX     gyroY     gyroZ
# 0         -0.957642        0.261536 -0.011266  0.010706 -0.026798
# 1         -0.972656        0.240631 -0.011384  0.020283 -0.012963
# ...
